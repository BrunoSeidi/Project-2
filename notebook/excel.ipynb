# %%
import pandas as pd

# %%
df1 = pd.read_excel('kits.xlsx')

# %%
df1.head(5)
# Out:
#   ACCESSORY TERMINAL BOX
# 0              AIR FILTER
# 1           ALUMINIUM FAN
# 2          BEARING CAP DE
# 3         BEARING CAP NDE
# 4        BEARING SET 6201

# %%
tuple(df1.itertuples(index=True))
# Out:
# (Pandas(Index=0, _1='AIR FILTER'),
#  Pandas(Index=1, _1='ALUMINIUM FAN'),
#  Pandas(Index=2, _1='BEARING CAP DE'),
#  Pandas(Index=3, _1='BEARING CAP NDE'),
#  Pandas(Index=4, _1='BEARING SET 6201'),
#  Pandas(Index=5, _1='BEARING SET 6202'),
#  Pandas(Index=6, _1='BEARING SET 6203'),
#  Pandas(Index=7, _1='BEARING SET 6204'),
#  Pandas(Index=8, _1='BEARING SET 6205'),
#  Pandas(Index=9, _1='BEARING SET 6206'),
#  Pandas(Index=10, _1='BEARING SET 6207'),
#  Pandas(Index=11, _1='BEARING SET 6208'),
#  Pandas(Index=12, _1='BEARING SET 6209'),
#  Pandas(Index=13, _1='BEARING SET 6211'),
#  Pandas(Index=14, _1='BEARING SET 6212'),
#  Pandas(Index=15, _1='BEARING SET 6307'),
#  Pandas(Index=16, _1='BEARING SET 6308'),
#  Pandas(Index=17, _1='BEARING SET 6309'),
#  Pandas(Index=18, _1='BEARING SET 6311'),
#  Pandas(Index=19, _1='BEARING SET 6312'),
#  Pandas(Index=20, _1='BEARING SET 6314'),
#  Pandas(Index=21, _1='BEARING SET 6316'),
#  Pandas(Index=22, _1='BEARING SET 6319'),
# ...
